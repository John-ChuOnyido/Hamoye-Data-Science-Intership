# %%
#importing all the necessary libray for 
#reading and visualization of the datasets
import numpy as np 
import pandas as pd
import seaborn as sns

#Importing the modules and the library for regression 
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from  sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
df = pd.read_csv("energydata_complete.csv")
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
#    RH_out  Windspeed  Visibility  Tdewpoint        rv1        rv2
# 0    92.0   7.000000   63.000000        5.3  13.275433  13.275433
# 1    92.0   6.666667   59.166667        5.2  18.606195  18.606195
# 2    92.0   6.333333   55.333333        5.1  28.642668  28.642668
# 3    92.0   6.000000   51.500000        5.0  45.410389  45.410389
# 4    92.0   5.666667   47.666667        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
#df.info()

# %%
#df.describe().T

# %%
simple_linear_reg_df = df[["T2","T6"]].sample(15,random_state=2)
simple_linear_reg_df
# Out:
#               T2         T6
# 1117   17.426667  -4.238889
# 16275  22.760000  14.690000
# 13272  21.230000   8.926667
# 3160   21.100000   7.690000
# 19210  21.856667  10.800000
# 8260   17.356667   5.000000
# 12299  19.000000   5.300000
# 13505  22.700000  17.133333
# 12913  19.593333   7.545000
# 17788  21.890000   9.190000
# 17894  21.500000   5.160000
# 7665   19.142857   0.937500
# 10165  18.000000   0.200000
# 18809  22.400000  16.833333
# 8737   17.066667   1.900000

# %%
scaler = MinMaxScaler()
#Normalised_df = pd.DataFrame(df,columns=df.columns)
features_df = df.drop(columns=["date","lights"])
app_target = df["Appliances"]

# %%
x_train,x_test,y_train,y_test = train_test_split(features_df,app_target,test_size=0.3,random_state=1)

# %%
linear_model = LinearRegression()
linear_model.fit(x_train,y_train)
predicted_values = linear_model.predict(x_test)

# %%
r2_score = r2_score(y_test,predicted_values)
r2_score = round(r2_score,3)
r2_score
# Out:
# 1.0

# %%
mae = mean_absolute_error(y_test,predicted_values)
mae = round(mae,3)
mae
# Out:
# 0.0

# %%
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 3)
# Out:
# 0.0

# %%
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
rmse = round(rmse,3)
rmse
# Out:
# 0.0

# %%
ridge_leg = Ridge(alpha = 0.5)
ridge_leg.fit(x_train,y_train)
# Out:
# Ridge(alpha=0.5)

# %%
from sklearn.linear_model import Lasso
lasso_leg = Lasso(alpha = 0.001)
lasso_leg.fit(x_train,y_train)


def get_weights_df(model,feat,col_name):

  weights= pd.Series(model.coef_,feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ["Features", col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, "Linear_Model_Weight")
ridge_weights_df = get_weights_df(ridge_leg, x_train, "Ridge_Weight")
lasso_weights_df = get_weights_df(lasso_leg, x_train, "Lasso_Weight")

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on="Features")
final_weights = pd.merge(final_weights,lasso_weights_df,on="Features")
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_Weight
# 0            T1        -7.147336e-14  2.701141e-09           0.0
# 1            T4        -2.150379e-14  1.060119e-08           0.0
# 2         T_out        -2.094099e-14 -4.568266e-08           0.0
# 3            T8        -1.749813e-14  3.485049e-08           0.0
# 4          RH_1        -1.576257e-14  6.342090e-08           0.0
# 5          RH_4        -1.528209e-14  4.893066e-09           0.0
# 6          RH_3        -1.033998e-14  1.920810e-08           0.0
# 7        RH_out        -3.875923e-15 -4.312237e-09          -0.0
# 8     Windspeed        -3.874320e-15  8.579479e-09           0.0
# 9          RH_9        -2.097130e-15 -6.417079e-09          -0.0
# 10         RH_5        -1.545979e-15  1.052953e-09           0.0
# 11           T7        -8.999654e-16  5.093967e-09           0.0
# 12          rv1        -8.338960e-16 -1.902208e-10          -0.0
# 13          rv2        -8.338960e-16  1.299213e-10          -0.0
# 14  Press_mm_hg        -2.106472e-16  4.645026e-10          -0.0
# 15         RH_8         5.286419e-16 -2.307698e-08          -0.0
# 16   Visibility         5.628558e-16  7.274777e-10           0.0
# 17         RH_6         3.516154e-15  1.656834e-09          -0.0
# 18    Tdewpoint         5.063251e-15  2.324482e-08           0.0
# 19         RH_7         5.480919e-15 -7.263238e-09          -0.0
# 20           T6         1.596435e-14  3.117610e-08           0.0
# 21         RH_2         1.884628e-14 -5.541316e-08          -0.0
# 22           T9         1.957103e-14 -9.161901e-08           0.0
# 23           T5         2.290107e-14  5.178550e-09           0.0
# 24           T3         2.737262e-14  1.048009e-07           0.0
# 25           T2         9.248261e-14 -7.809382e-08           0.0
# 26   Appliances         1.000000e+00  1.000000e+00           1.0
